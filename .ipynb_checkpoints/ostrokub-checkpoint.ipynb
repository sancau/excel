# %%
# coding=utf-8

import os, sys
import openpyxl

"""
DATA CONFIG
"""
INDEX = 0
NAME = 1
SIZE = 6
AMOUNT = 11
MATERIAL = 12
UNITS = 17
MATERIAL_AMOUNT = 19
STANDART = 21
COMMENT = 24

PAYLOAD_DATA_INDEXES = [
    INDEX, NAME, SIZE, 
    AMOUNT, MATERIAL, UNITS, 
    MATERIAL_AMOUNT, STANDART, 
    COMMENT
]

FISRT_LIST = 'Лист1'
FISRT_LIST_FIRST_DATA_ROW = 22
OTHER_LISTS_FIRST_DATA_ROW = 2

REPEAT_SYMBOLS = ['——ıı——',]

"""
SCRIPT CONFIG
"""
DEFAULT_DIR_PATH = os.path.dirname(sys.argv[0])
DEFUALT_RESULT_FILE_NAME = 'output.xls'
DEFAULT_RESULT_FILE_PATH = \
    os.path.join(DEFAULT_DIR_PATH, DEFUALT_RESULT_FILE_NAME)

"""
LOGIC
"""    
def get_files(dir_path=DEFAULT_DIR_PATH):
    """
    Returns list of excel file paths in
    a given directory
    """
    result = []
    for path, subdirs, files in os.walk(dir_path):
        for file in files:
            filename, file_extension = os.path.splitext(file)
            if file_extension in ['.xls', '.xlsx']:
                file_path = os.path.join(path, file)
                print(file_path)
                result.append(file_path)
    
    # DEBUG PRINTS
    print('________________________________________________')
    print(' ')
    print('Index | Name | Size | Amount | Material | Units | Material Amount | Standart | Comment')
    print('________________________________________________')
    print(' ')
    return result

def merge(rows):
    """
    Parse a row of the table.
    Add data to result dict.
    
    If this key exists in the dict process its params
    and add the amount
    Else - add new key in dict
    """
    # clean data from openpyxl wrappers
    plain_rows = []
    for row in rows:
        plain_row = [item.value for item in row]               
        plain_rows.append(plain_row)
    
    #handle repeat sybmols
    for row_index, plain_row in enumerate(plain_rows):
        for value_index, value in enumerate(plain_row):
            if value in REPEAT_SYMBOLS:
                plain_row[value_index] = plain_rows[row_index - 1][value_index] 
    
    filtered_rows = [
        [cell for cell_index, cell in enumerate(row) if cell_index in PAYLOAD_DATA_INDEXES]\
        for row in plain_rows if row[NAME] is not None and row[INDEX] is not None
    ] 
    for row in filtered_rows:
        print(row)
    
    def get_size(row):
        """
        Returns main size criteria for a given row.
        """
        pass

    def get_match(row):
        """
        Checks if given row has a match in output array.
        
        if there is a row with the same STANDART, check if the MATERIAL is the same
        if so -> check if main size criteria is the same 
        if yes
            return the row that is the match           
        """
        pass
    
    def merge_data(new, existed):
        """
        Appends row data to an existed row if match was confirmed.
        
        Apply merge politics here to inject new in existed.
        """
        pass
    
    # generate output dictionary
    output = {}
    for row in plain_rows:
        if not row[NAME] in output and not row[NAME] == None:
            output[row[NAME]] = {
                'name': row[NAME],
                'size': row[SIZE],
                'amount': row[AMOUNT],
                'material': row[MATERIAL],
                'units': row[UNITS],
                'material_amount': row[MATERIAL_AMOUNT],
                'standart': row[STANDART],
                'comment': row[COMMENT]
            }
        else:
            # APPLY MERGE POLITICS HERE
            pass
    return output

def build_results_file(results_dict, results_file_path=DEFAULT_RESULT_FILE_PATH):
    """
    Build an excel file based on results dict and 
    a given path.
    """
    pass

def process(dir_path=DEFAULT_DIR_PATH, result_file_path=DEFAULT_RESULT_FILE_PATH):
    try:
        files = get_files(dir_path)
        rows_to_process = []
        if files:
            for file in files:
                workbook = openpyxl.load_workbook(filename=file)   
                for sheet in workbook:
                    for row in sheet:
                        # add rows by certain condition
                        row_index = (lambda x: x[0].row)(row)
                        if (sheet is not workbook[FISRT_LIST] \
                        and row_index >= OTHER_LISTS_FIRST_DATA_ROW) \
                            or row_index >= FISRT_LIST_FIRST_DATA_ROW:
                            rows_to_process.append(row) 
                            
            results_dict = merge(rows_to_process)
            # build_results_file(results_dict) 
            # print('Success')
        else:
            print('No files to process')
    
    except Exception as ex:
        print('Error while processing')
        print(ex)

# %%
dir_path = '/home/sancau/Desktop/kub'
process(dir_path)
# Out:
# /home/sancau/Desktop/kub/testdata/test2.xlsx
# /home/sancau/Desktop/kub/testdata/test.xlsx
# ________________________________________________
#
# Index | Name | Size | Amount | Material | Units | Material Amount | Standart | Comment
# ________________________________________________
#
# [1, 'Лист', '≠1×15×20', 1, 'Ст 20', 'м²', 0.001, 'Г.1577-93', None]
# [2, 'Круг', 'Ø20×30', 1, 'Ст 12Х18Н9Т', None, None, 'Г.5632-72', None]
# [3, 'Круг', 'Ø22×17', 1, 'Ст 12Х18Н9Т', None, None, 'Г.5632-72', None]
# [4, 'Шестигранник 5,5h-12', 'L=270', None, 'Ст 45', 'мм', None, 'Г.1051-73', None]
# [5, 'Круг', 'Ø6×25', None, 'Ст 12Х18Н10Т', None, None, 'Г.5632-72', None]
# [6, 'Круг', 'Ø7×120', None, 'Ст 20', None, None, 'Г.1050-88', None]
# [7, 'Круг', 'Ø7×180', None, 'Ст 20', None, None, 'Г.1050-88', None]
# [8, 'Круг', 'Ø7×600', None, 'Ст 20', None, None, 'Г.1050-88', None]
# [9, 'Круг', 'Ø8×40', None, 'Ст 20', None, None, 'Г.1050-88', None]
# [10, 'Круг', 'Ø50×20', None, 'Ст 20', None, None, 'Г.1050-88', None]
# [11, 'Круг', 'Ø260×55', None, 'Ст 20', None, None, 'Г.1050-88', None]
# [12, 'Круг', '≠5×45×80', 8, 'Ст 3', 'м²', 0.26, 'Г.585-2005', None]
# [13, 'Круг', '≠5×30×30', 16, 'Ст 3', None, None, 'Г.585-2005', None]
# [14, 'Круг', '≠5×255×255', 2, 'Ст 3', None, None, 'Г.585-2005', None]
# [15, 'Проволока', 'Ø0,5', None, 'О-2С', 'г', 0.3, 'Г.3282-74', None]
# [16, 'Лист', '≠6×10×30', 1, 'Ст 3', 'м²', 0.001, 'Г.585-2005', 'оснастка']
# [17, 'Лист', '≠2×24×24', 2, 'Д16', 'м²', 0.002, 'Г.4784-97', 'обкладки']
# [18, 'Лист', '≠1×30×55', 1, 'Д16', 'м²', 0.002, 'Г.4784-97', None]
# [19, 'Лист', '≠6×50×50', 1, 'Д16', 'м²', 0.004, 'Г.4784-97', None]
# [20, 'Лист', '≠20×175×175', 1, 'АМг6', 'м²', 0.112, 'Г.4784-97', None]
# [21, 'Лист', '≠20×210×210', 1, 'АМг6', None, None, 'Г.4784-97', None]
# [22, 'Круг', 'Ø8×80', None, 'Д16', None, None, 'Г.4784-97', None]
# [23, 'Круг', 'Ø35×30', None, 'Д16', None, None, 'Г.4784-97', None]
# [24, 'Круг', 'Ø50×16', None, 'АМг6', None, None, 'Г.4784-97', None]
# [25, 'Круг', 'Ø10×30', None, 'ЛС59-1', None, None, 'Г.15527-2004', None]
# [26, 'Лента', '≠0,3×10×30', 4, 'БрБ2', 'м²', 0.002, 'Г.1789-70', None]
# [27, 'Лента', '≠0,2×15×20', 12, 'БрКМц3-1', 'м²', 0.005, 'Г.4748-70', None]
# [28, 'Пруток', 'Ø5×180', None, 'БрБ2', None, None, 'Г.15834-77', None]
# [29, 'Проволока', 'Ø8,5×5400', None, None, None, None, 'Г.15835-2013', None]
# [30, 'Проволока', 'Ø8,5×9000', None, None, None, None, 'Г.15835-2013', None]
# [31, 'Круг', 'Ø45×150', None, 'ВНД-МП', None, None, None, None]
# [32, 'Фольга', '≠0,09×20×95', 12, 'ДПРХХ МДП', 'м²', 0.034, 'Г.18394-73', None]
# [33, 'Лист', '≠2×185×545', 1, 'АМг6М', 'м²', 0.151, 'Г.4784-97', None]
# [34, 'Проволока', 'Ø0,4', None, 'ММ', 'м', 5, 'ТУ16К71-087-90', None]
# [35, 'Проволока', 'Ø1,0', None, 'ММ', 'м', 1.3, 'ТУ16К71-087-90', '0,006 кг']
# [36, 'Проволока', 'Ø0,6', None, 'ММ', 'м', 0.18, 'ТУ16К71-087-90', None]
# [37, 'Припой', 'Т1,0А', None, 'ПОС-61', 'кг', 0.3, 'Г.21931-76', None]
# [38, 'Припой', 'Т1,0А', None, 'ПОСК50-18', 'кг', 0.16, 'Г.21931-76', None]
# [39, 'Стеклотекстолит', '≠1×24×24', 2, 'СТ-ЭТФ', 'м²', 0.002, 'Г.12652-74', None]
# [40, 'Капролон', 'Ø10×10', 12, 'ПА6, блочный, м.Б', None, None, 'ТУ6-05-988-87', None]
# [41, 'Капролон', 'Ø70×135', None, 'ПА6, блочный, м.Б', None, None, 'ТУ6-05-988-87', None]
# [42, 'Капролон', 'Ø80×55', None, 'ПА6, блочный, м.Б', None, None, 'ТУ6-05-988-87', None]
# [43, 'Полиамид ', None, None, '610 литьевой', 'г', 6, 'Г.10589-87', None]
# [44, 'Трубка', '0,6×0,2', None, 'Ф-4Д', 'м', 4, 'Г.22056-76', None]
# [45, 'Трубка', '1,5×0,3', None, 'Ф-4Д', 'м', 0.8, 'Г.22056-76', None]
# [46, 'Трубка', '3×0,4', None, 'Ф-4Д', None, 1.5, 'Г.22056-76', None]
# [47, 'Пленка', '0,01×10', None, 'Ф-4ЭО, 1с', 'кг', 0.006, 'Г.24222-80', None]
# [48, 'Лента', '15×0,20', None, 'ПВХ, 1с.', 'м', 1, 'Г.16214-86', None]
# [49, 'Стеклолакоткань', 0.15, None, 'ЛСП-130/155, в.с.', 'м²', 0.2, 'ТУ16-90И37.0003.003ТУ', None]
# [50, 'Провод', '1×0,2', None, 'МС16-13', 'м', 12, 'ТУ16-505.083-78', None]
# [51, 'Провод', '1×0,35', None, 'МС16-13', 'м', 2, 'ТУ16-505.083-78', None]
# [52, 'Провод', 0.28, None, 'ПЭТВ-2', 'м', 4, 'ТУ16-502.003-82', None]
# [53, 'Пластина', '≠2×100×100', 1, 'ИРП-1118', 'м²', 0.015, 'ОСТ38533-73', None]
# [54, 'Пластина', '≠3×50×50', 1, 'ИРП-1118', 'м²', 0.004, 'ОСТ38533-73', None]
# [55, 'Пластина', '≠1×40×40', 1, 'ИРП-1267', 'м²', 0.002, 'ТУ38-005-838-70', None]
# [56, 'Пластина', '≠2×35×35', 1, 'ИРП-1267', 'м²', 0.002, 'ТУ38-005-838-70', None]
# [57, 'Нитки', None, None, '3К', 'м', 1.3, 'ОСТ17-330-2002', None]
# [58, 'Нитки', None, None, '10К', 'м', 1, 'ОСТ17-330-2002', None]
# [59, 'Бумага', None, None, 'БДХ', 'кг', 0.2, 'ТУ13-73080001-669-84', None]
# [60, 'Флюс', None, None, 'ФКСп', 'кг', 0.12, 'ОСТ4ГО.033.200', None]
# [61, 'Паяльная паста', None, None, 'Sn62Pb36Ag2', 'кг', 0.005, None, None]
# [62, 'Лак', None, None, 'УР-231', 'кг', 0.13, 'ТУ6-21-14-90', None]
# [63, 'Клей', None, None, 'ВК-9', 'кг', 0.01, 'ОСТ107.460007.009-02', None]
# [64, 'Клей', None, None, 'ВК-9 без наполнителя', 'кг', 0.05, 'ОСТ107.460007.009-02', None]
# [65, 'Герметик', None, None, 'Унигерм 2М', 'кг', 0.01, 'ТУ6-02-61-89', None]
# [66, 'Смазка', None, None, 'ЦИАТИМ-221', 'кг', 0.03, 'Г.9433-80', None]
# [67, 'Лак', None, None, 'АК-113', 'кг', 0.01, 'Г.23832-89', None]
# [68, 'Герметик', None, None, 'Унигерм 6', 'кг', 0.003, None, None]
# [69, 'Мастика битумная', None, None, '№ 2', 'кг', 0.002, 'Г.18680-73', None]
# [70, 'Краска', None, None, 'МКЭчерная', 'кг', 0.025, 'ОСТ107.9.4003-96', None]
# [71, 'Эмаль', None, None, 'ЭП-51 красная', 'кг', 0.02, 'Г.9640-85', 'стопорение']
# [72, 'Эмаль', None, None, 'ПФ-115 белая', 'кг', 0.005, 'Г.6465-76', 'гравировка']
# [73, 'Эмаль', None, None, 'ЭП-140 красная', 'кг', 0.002, 'Г.24709-81', 'окраска']
# [74, 'Эмаль', None, None, 'ХВ-518 защитная', 'кг', 0.1, 'ТУ2313-034-05015319-2001', 'окраска']
# [75, 'Спирт этиловый', None, None, '"Экстра"', 'кг', 0.1, 'Г.18300-87', None]
# [1, 'Круг', 'Ø35×40', 1, 'Ст 12Х18Н10Т', None, None, 'Г.5582-75', None]
# [2, 'Круг', 'Ø60×55', 1, 'Ст 12Х18Н10Т', None, None, 'Г.5582-75', None]
# [3, 'Круг', 'Ø100×50', 1, 'Ст 12Х18Н10Т', None, None, 'Г.5582-75', None]
# [4, 'Круг', 'Ø120×96', 1, 'Ст 12Х18Н10Т', None, None, 'Г.5582-75', None]
# [5, 'Круг', 'Ø12×25', 2, 'Ст 12Х18Н9Т', None, None, 'Г.5582-75', None]
# [6, 'Труба', 'Ø114×5×125', None, 'Ст 12Х18Н10Т', None, None, 'Г.5582-75', None]
# [7, 'Лента', '≠0,5×25×40', 1, '2П', 'м²', 0.002, 'Г.21996-76', None]
# [8, 'Лист', '≠3×60×60', 1, 'Ст 12Х18Н10Т', 'м²', 0.034, 'Г.5582-75', None]
# [9, 'Лист', '≠3×18×250', 1, 'Ст 12Х18Н10Т', None, None, 'Г.5582-75', None]
# [10, 'Лист', '≠3×120×120', 1, 'Ст 12Х18Н10Т', None, None, 'Г.5582-75', None]
# [11, 'Круг', 'Ø30×40', 1, 'ВНМ3-2', None, None, 'ТУ48-19-90-74', None]
# [12, 'Лист', '≠2×10×10', 2, 'Д16', None, None, 'Г.4784-97', 'обкладки']
# [13, 'Лента', '≠0,2×10×10', 3, 'ДПРНМ НД Л63', 'м²', None, 'Г.2208-75', None]
# [14, 'Лента', '≠0,5×10×10', 1, 'ДПРНМ НД Л63', 'м²', None, 'Г.2208-75', None]
# [15, 'Свинец', None, None, 'С3', 'кг', 9, 'Г.3778-77', None]
# [16, 'Герметик', None, None, 'Унигерм 6', 'кг', 0.01, 'ТУ6-01-1285-84', None]
# [17, 'Клей', None, None, 'БФ-4', 'кг', 0.01, 'Г.12172-74', None]
# [18, 'Эмаль', None, None, 'ЭП-51 черная', 'кг', 0.005, 'Г.9640-85', 'гравировка']
# [19, 'Эмаль', None, None, 'ЭП-51 красная', 'кг', 0.005, 'Г.9640-85', 'окраска']
# [20, 'Эмаль', None, None, 'ЭП-51 желтая', 'кг', 0.005, 'Г.9640-85', 'окраска']
# [21, 'Нитки крученые капроновые', None, None, '3К', 'м', 1, 'ОСТ 17-330-2002', None]
# [22, 'Шнур', None, None, 'ШКП-60', 'м', 0.7, 'ТУ17РСФСР 44-2660-80', None]

# %%
# MATERIAL -> SIZE -> GOST ; IF NAME1 != NAME2 -> NAME1, NAME2; SIZES = [[SIZE1, AMOUNT1], [SIZE2, AMOUNT2]].JOIN(';')

# %%
#SPACE STRIP
